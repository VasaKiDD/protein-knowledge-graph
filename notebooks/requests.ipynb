# %% [markdown]
# # Hands on interaction graphs

# %%
import subprocess
subprocess.Popen(["python3","-m","http.server"])
from pybiographs import InteractionGraph, OntologyGraph, Mappings

# %% [markdown]
# First let's load graphs. If the graph are not loaded, the package will download them for you. The graphs are wrapped in a class but have the same methods as in networkx : https://networkx.github.io/documentation/stable/.

# %%
directed_graph = InteractionGraph(directed=True)
undirected_graph = InteractionGraph(directed=False)
print("protein nodes in directed :", len(directed_graph.nodes()))
print("interaction edges in directed :", len(directed_graph.edges()))
print("protein nodes in undirected :", len(undirected_graph.nodes()))
print("interaction edges in undirected :", len(undirected_graph.edges()))
# Out:
# protein nodes in directed : 15531
# interaction edges in directed : 1665684
# protein nodes in undirected : 18553
# interaction edges in undirected : 5542412

# %% [markdown]
# Let's load the useful dictionaries to deal with the data explained in readme :

# %%
maps = Mappings()
print(maps.names)
# Out:
# ('biological_processes_union', 'cell_components_union', 'covid_go_to_name', 'metabolites_id_to_name', 'molecular_functions_union', 'gene_to_proteins', 'go_to_name', 'tissue_num_mapping')

# %% [markdown]
# Let's search for all protein that have serotonin and receptor in node attributes ontology and info :

# %%
sub_graph = undirected_graph.sub_graph_by_node_regex_search(regex = "[sS]erotonin.*receptor|receptor.*[sS]erotonin", 
                                                          spec="i_o",
                                                         score_threshold = 0.9,
                                                         expression_threshold = 0.0)
print("nodes in sub_graph :", len(list(sub_graph.nodes())))
print("edges in subgraph :", len(list(sub_graph.edges())))
# Out:
# nodes in sub_graph : 36
# edges in subgraph : 159

# %% [markdown]
# The same but for founding the proteins involved in synaptic signals in all attributes:

# %%
sub_graph = undirected_graph.sub_graph_by_node_regex_search(regex = "synap.*signal|signal.*synap", 
                                                          spec="i_o_p_m",
                                                         score_threshold = 0.9,
                                                         expression_threshold = 0.0)
print("nodes in sub_graph :", len(list(sub_graph.nodes())))
print("edges in subgraph :", len(list(sub_graph.edges())))
# Out:
# nodes in sub_graph : 470
# edges in subgraph : 3761

# %% [markdown]
# Let's print them :

# %%
undirected_graph.print_sub_graph_nodes(sub_graph, print_spec="i_o", limit=10)
# Out:
# O60755  :  other_protein
# info : Galanin receptor type 3; Receptor for the hormone galanin. Receptor for the hormone spexin-1
# cellular components :
# 	synapse
# 	integral component of plasma membrane
# 	9+0 non-motile cilium
# molecular functions :
# 	peptide hormone binding
# 	galanin receptor activity
# biological processes :
# 	peptide hormone binding
# 	galanin receptor activity
#
#
# P07510  :  other_protein
# info : Acetylcholine receptor subunit gamma; After binding acetylcholine, the AChR responds by an extensive change in conformation that affects all subunits and leads to opening of an ion-conducting channel across the plasma membrane; Cholinergic receptors nicotinic subunits
# cellular components :
# 	neuron projection
# 	postsynaptic membrane
# 	acetylcholine-gated channel complex
# molecular functions :
# 	protein binding
# 	acetylcholine-gated cation-selective channel activity
# 	acetylcholine receptor activity
# 	acetylcholine binding
# biological processes :
# 	protein binding
# 	acetylcholine-gated cation-selective channel activity
# 	acetylcholine receptor activity
# 	acetylcholine binding
#
#
# Q9UBN1  :  metabolome_protein
# info : Voltage-dependent calcium channel gamma-4 subunit; Regulates the trafficking and gating properties of AMPA- selective glutamate receptors (AMPARs). Promotes their targeting to the cell membrane and synapses and modulates their gating properties by slowing their rates of activation, deactivation and desensitization and by mediating their resensitization. Does not show subunit-specific AMPA receptor regulation and regulates all AMPAR subunits. Thought to stabilize the calcium channel in an inactivated (closed) state
# cellular components :
# 	cell surface
# 	integral component of postsynaptic density membrane
# 	glutamatergic synapse
# 	endocytic vesicle membrane
# 	cell body
# 	L-type voltage-gated calcium channel complex
# 	AMPA glutamate receptor complex
# 	somatodendritic compartment
# molecular functions :
# 	ionotropic glutamate receptor binding
# 	voltage-gated calcium channel activity
# 	calcium channel regulator activity
# biological processes :
# 	ionotropic glutamate receptor binding
# 	voltage-gated calcium channel activity
# 	calcium channel regulator activity
#
#
# Q14957  :  metabolome_protein
# info : Glutamate receptor ionotropic, NMDA 2C; Component of NMDA receptor complexes that function as heterotetrameric, ligand-gated ion channels with high calcium permeability and voltage-dependent sensitivity to magnesium. Channel activation requires binding of the neurotransmitter glutamate to the epsilon subunit, glycine binding to the zeta subunit, plus membrane depolarization to eliminate channel inhibition by Mg(2+). Sensitivity to glutamate and channel kinetics depend on the subunit composition (Probable). Plays a role in regulating the balance between excitatory and inhibitory activit [...]
# cellular components :
# 	cell
# 	glutamatergic synapse
# 	postsynaptic density membrane
# 	NMDA selective glutamate receptor complex
# molecular functions :
# 	protein binding
# 	transmitter-gated ion channel activity involved in regulation of postsynaptic membrane potential
# 	NMDA glutamate receptor activity
# 	glutamate-gated calcium ion channel activity
# biological processes :
# 	protein binding
# 	transmitter-gated ion channel activity involved in regulation of postsynaptic membrane potential
# 	NMDA glutamate receptor activity
# 	glutamate-gated calcium ion channel activity
#
#
# Q9NZN1  :  other_protein
# info : Interleukin-1 receptor accessory protein-like 1; May regulate secretion and presynaptic differentiation through inhibition of the activity of N-type voltage-gated calcium channel. May activate the MAP kinase JNK. Plays a role in neurite outgrowth (By similarity). During dendritic spine formation can bidirectionally induce pre- and post-synaptic differentiation of neurons by trans- synaptically binding to PTPRD (By similarity); Belongs to the interleukin-1 receptor family
# cellular components :
# 	cytoplasm
# 	integral component of membrane
# 	dendrite
# 	cell surface
# 	axon
# 	glutamatergic synapse
# 	postsynaptic membrane
# molecular functions :
# 	signaling receptor binding
# 	interleukin-1 binding
# 	NAD+ nucleotidase, cyclic ADP-ribose generating
# 	NAD(P)+ nucleosidase activity
# biological processes :
# 	signaling receptor binding
# 	interleukin-1 binding
# 	NAD+ nucleotidase, cyclic ADP-ribose generating
# 	NAD(P)+ nucleosidase activity
#
#
# P47900  :  metabolome_protein
# info : P2Y purinoceptor 1; Receptor for extracellular adenine nucleotides such as ATP and ADP. In platelets binding to ADP leads to mobilization of intracellular calcium ions via activation of phospholipase C, a change in platelet shape, and probably to platelet aggregation; Belongs to the G-protein coupled receptor 1 family
# cellular components :
# 	mitochondrion
# 	dendrite
# 	cilium
# 	basolateral plasma membrane
# 	apical plasma membrane
# 	glutamatergic synapse
# 	postsynaptic membrane
# 	cell body
# 	postsynaptic density
# 	integral component of presynaptic active zone membrane
# molecular functions :
# 	ATP binding
# 	protein heterodimerization activity
# 	scaffold protein binding
# 	ADP binding
# 	G protein-coupled ADP receptor activity
# 	G protein-coupled ATP receptor activity
# 	A1 adenosine receptor binding
# biological processes :
# 	ATP binding
# 	protein heterodimerization activity
# 	scaffold protein binding
# 	ADP binding
# 	G protein-coupled ADP receptor activity
# 	G protein-coupled ATP receptor activity
# 	A1 adenosine receptor binding
#
#
# Q15700  :  other_protein
# info : Disks large homolog 2; Required for perception of chronic pain through NMDA receptor signaling. Regulates surface expression of NMDA receptors in dorsal horn neurons of the spinal cord. Interacts with the cytoplasmic tail of NMDA receptor subunits as well as inward rectifying potassium channels. Involved in regulation of synaptic stability at cholinergic synapses. Part of the postsynaptic protein scaffold of excitatory synapses (By similarity); Membrane associated guanylate kinases
# cellular components :
# 	cytosol
# 	glutamatergic synapse
# 	perikaryon
# 	postsynaptic density membrane
# 	juxtaparanode region of axon
# 	axon cytoplasm
# molecular functions :
# 	kinase binding
# 	guanylate kinase activity
# 	structural constituent of postsynaptic density
# biological processes :
# 	kinase binding
# 	guanylate kinase activity
# 	structural constituent of postsynaptic density
#
#
# Q9C026  :  other_protein
# info : E3 ubiquitin-protein ligase TRIM9; E3 ubiquitin-protein ligase which ubiquitinates itself in cooperation with an E2 enzyme UBE2D2/UBC4 and serves as a targeting signal for proteasomal degradation. May play a role in regulation of neuronal functions and may also participate in the formation or breakdown of abnormal inclusions in neurodegenerative disorders. May act as a regulator of synaptic vesicle exocytosis by controlling the availability of SNAP25 for the SNARE complex formation; Belongs to the TRIM/RBCC family
# cellular components :
# 	cytoskeleton
# 	dendrite
# 	synaptic vesicle
# 	presynaptic cytosol
# molecular functions :
# 	zinc ion binding
# 	ubiquitin protein ligase activity
# 	protein homodimerization activity
# 	protein domain specific binding
# 	SNARE binding
# biological processes :
# 	zinc ion binding
# 	ubiquitin protein ligase activity
# 	protein homodimerization activity
# 	protein domain specific binding
# 	SNARE binding
#
#
# P29275  :  metabolome_protein
# info : Adenosine receptor A2b; Receptor for adenosine. The activity of this receptor is mediated by G proteins which activate adenylyl cyclase
# cellular components :
# 	integral component of plasma membrane
# 	Schaffer collateral - CA1 synapse
# 	glutamatergic synapse
# molecular functions :
# 	protein binding
# 	G protein-coupled adenosine receptor activity
# biological processes :
# 	protein binding
# 	G protein-coupled adenosine receptor activity
#
#
# P08908  :  metabolome_protein
# info : 5-hydroxytryptamine receptor 1A; G-protein coupled receptor for 5-hydroxytryptamine (serotonin). Also functions as a receptor for various drugs and psychoactive substances. Ligand binding causes a conformation change that triggers signaling via guanine nucleotide-binding proteins (G proteins) and modulates the activity of down-stream effectors, such as adenylate cyclase. Beta-arrestin family members inhibit signaling via G proteins and mediate activation of alternative signaling pathways. Signaling inhibits adenylate cyclase activity and activates a phosphatidylinositol-calcium second  [...]
# cellular components :
# 	synapse
# 	integral component of plasma membrane
# 	dendrite
# molecular functions :
# 	G protein-coupled serotonin receptor activity
# 	serotonin binding
# 	receptor-receptor interaction
# biological processes :
# 	G protein-coupled serotonin receptor activity
# 	serotonin binding
# 	receptor-receptor interaction

# %% [markdown]
# Now instead let's search all the protein involved in synaptic signals in synapse:
# * GO:0099536 : synaptic signaling
# * GO:0045202 : synapse

# %%
sub_graph = undirected_graph.sub_graph_by_node_ontology_search(ontology_query = ["and", "GO:0099536", "GO:0045202"])
print("nodes in sub_graph :", len(list(sub_graph.nodes())))
print("edges in subgraph :", len(list(sub_graph.edges())))
# Out:
# nodes in sub_graph : 303
# edges in subgraph : 12913

# %% [markdown]
# Note that search by ontology is less powerful than by regex because it searches the specific groups and not in the protein info attribute. This can be used to do an automatic ontology anotation.

# %%
undirected_graph.print_sub_graph_nodes(sub_graph, print_spec="i_o", limit=10)
# Out:
# P48145  :  other_protein
# info : Neuropeptides B/W receptor type 1; Interacts specifically with a number of opioid ligands. Receptor for neuropeptides B and W, which may be involved in neuroendocrine system regulation, food intake and the organization of other signals. Has a higher affinity for neuropeptide B
# cellular components :
# 	synapse
# 	neuron projection
# 	integral component of plasma membrane
# molecular functions :
# 	protein binding
# 	neuropeptide binding
# 	neuropeptide receptor activity
# 	opioid receptor activity
# biological processes :
# 	protein binding
# 	neuropeptide binding
# 	neuropeptide receptor activity
# 	opioid receptor activity
#
#
# O60755  :  other_protein
# info : Galanin receptor type 3; Receptor for the hormone galanin. Receptor for the hormone spexin-1
# cellular components :
# 	synapse
# 	integral component of plasma membrane
# 	9+0 non-motile cilium
# molecular functions :
# 	peptide hormone binding
# 	galanin receptor activity
# biological processes :
# 	peptide hormone binding
# 	galanin receptor activity
#
#
# Q8NCG7  :  metabolome_protein
# info : Sn1-specific diacylglycerol lipase beta; Catalyzes the hydrolysis of diacylglycerol (DAG) to 2- arachidonoyl-glycerol (2-AG), the most abundant endocannabinoid in tissues. Required for axonal growth during development and for retrograde synaptic signaling at mature synapses; Belongs to the AB hydrolase superfamily. Lipase family
# cellular components :
# 	nucleoplasm
# 	integral component of membrane
# 	lysosomal membrane
# 	postsynaptic membrane
# molecular functions :
# 	hydrolase activity
# 	metal ion binding
# biological processes :
# 	hydrolase activity
# 	metal ion binding
#
#
# P07510  :  other_protein
# info : Acetylcholine receptor subunit gamma; After binding acetylcholine, the AChR responds by an extensive change in conformation that affects all subunits and leads to opening of an ion-conducting channel across the plasma membrane; Cholinergic receptors nicotinic subunits
# cellular components :
# 	neuron projection
# 	postsynaptic membrane
# 	acetylcholine-gated channel complex
# molecular functions :
# 	protein binding
# 	acetylcholine-gated cation-selective channel activity
# 	acetylcholine receptor activity
# 	acetylcholine binding
# biological processes :
# 	protein binding
# 	acetylcholine-gated cation-selective channel activity
# 	acetylcholine receptor activity
# 	acetylcholine binding
#
#
# Q15768  :  other_protein
# info : Ephrin-B3; Cell surface transmembrane ligand for Eph receptors, a family of receptor tyrosine kinases which are crucial for migration, repulsion and adhesion during neuronal, vascular and epithelial development. Binds promiscuously Eph receptors residing on adjacent cells, leading to contact-dependent bidirectional signaling into neighboring cells. The signaling pathway downstream of the receptor is referred to as forward signaling while the signaling pathway downstream of the ephrin ligand is referred to as reverse signaling. May play a pivotal role in forebrain function. Binds to, an [...]
# cellular components :
# 	integral component of postsynaptic density membrane
# 	glutamatergic synapse
# 	hippocampal mossy fiber to CA3 synapse
# 	integral component of presynaptic membrane
# molecular functions :
# 	virus receptor activity
# 	ephrin receptor binding
# 	transmembrane-ephrin receptor activity
# biological processes :
# 	virus receptor activity
# 	ephrin receptor binding
# 	transmembrane-ephrin receptor activity
#
#
# P28335  :  metabolome_protein
# info : 5-hydroxytryptamine receptor 2C; G-protein coupled receptor for 5-hydroxytryptamine (serotonin). Also functions as a receptor for various drugs and psychoactive substances, including ergot alkaloid derivatives, 1- 2,5,-dimethoxy-4-iodophenyl-2-aminopropane (DOI) and lysergic acid diethylamide (LSD). Ligand binding causes a conformation change that triggers signaling via guanine nucleotide-binding proteins (G proteins) and modulates the activity of down-stream effectors. Beta-arrestin family members inhibit signaling via G proteins and mediate activation of alternative signaling pathway [...]
# cellular components :
# 	synapse
# 	cell
# 	integral component of plasma membrane
# 	dendrite
# molecular functions :
# 	identical protein binding
# 	1-(4-iodo-2,5-dimethoxyphenyl)propan-2-amine binding
# 	serotonin binding
# 	Gq/11-coupled serotonin receptor activity
# biological processes :
# 	identical protein binding
# 	1-(4-iodo-2,5-dimethoxyphenyl)propan-2-amine binding
# 	serotonin binding
# 	Gq/11-coupled serotonin receptor activity
#
#
# Q9NZN1  :  other_protein
# info : Interleukin-1 receptor accessory protein-like 1; May regulate secretion and presynaptic differentiation through inhibition of the activity of N-type voltage-gated calcium channel. May activate the MAP kinase JNK. Plays a role in neurite outgrowth (By similarity). During dendritic spine formation can bidirectionally induce pre- and post-synaptic differentiation of neurons by trans- synaptically binding to PTPRD (By similarity); Belongs to the interleukin-1 receptor family
# cellular components :
# 	cytoplasm
# 	integral component of membrane
# 	dendrite
# 	cell surface
# 	axon
# 	glutamatergic synapse
# 	postsynaptic membrane
# molecular functions :
# 	signaling receptor binding
# 	interleukin-1 binding
# 	NAD+ nucleotidase, cyclic ADP-ribose generating
# 	NAD(P)+ nucleosidase activity
# biological processes :
# 	signaling receptor binding
# 	interleukin-1 binding
# 	NAD+ nucleotidase, cyclic ADP-ribose generating
# 	NAD(P)+ nucleosidase activity
#
#
# Q14957  :  metabolome_protein
# info : Glutamate receptor ionotropic, NMDA 2C; Component of NMDA receptor complexes that function as heterotetrameric, ligand-gated ion channels with high calcium permeability and voltage-dependent sensitivity to magnesium. Channel activation requires binding of the neurotransmitter glutamate to the epsilon subunit, glycine binding to the zeta subunit, plus membrane depolarization to eliminate channel inhibition by Mg(2+). Sensitivity to glutamate and channel kinetics depend on the subunit composition (Probable). Plays a role in regulating the balance between excitatory and inhibitory activit [...]
# cellular components :
# 	cell
# 	glutamatergic synapse
# 	postsynaptic density membrane
# 	NMDA selective glutamate receptor complex
# molecular functions :
# 	protein binding
# 	transmitter-gated ion channel activity involved in regulation of postsynaptic membrane potential
# 	NMDA glutamate receptor activity
# 	glutamate-gated calcium ion channel activity
# biological processes :
# 	protein binding
# 	transmitter-gated ion channel activity involved in regulation of postsynaptic membrane potential
# 	NMDA glutamate receptor activity
# 	glutamate-gated calcium ion channel activity
#
#
# Q7L1I2  :  metabolome_protein
# info : Synaptic vesicle glycoprotein 2B; Probably plays a role in the control of regulated secretion in neural and endocrine cells
# cellular components :
# 	integral component of membrane
# 	neuron projection
# 	plasma membrane
# 	acrosomal vesicle
# 	synaptic vesicle membrane
# molecular functions :
# 	protein binding
# 	transmembrane transporter activity
# biological processes :
# 	protein binding
# 	transmembrane transporter activity
#
#
# Q9Y4I1  :  other_protein
# info : Unconventional myosin-Va; Processive actin-based motor that can move in large steps approximating the 36-nm pseudo-repeat of the actin filament. Involved in melanosome transport. Also mediates the transport of vesicles to the plasma membrane. May also be required for some polarization process involved in dendrite formation; Myosins, class V
# cellular components :
# 	cell
# 	Golgi apparatus
# 	membrane
# 	peroxisome
# 	insulin-responsive compartment
# 	early endosome
# 	melanosome
# 	neuronal cell body
# 	intermediate filament
# 	postsynapse
# 	photoreceptor outer segment
# 	glutamatergic synapse
# 	microtubule plus-end
# 	smooth endoplasmic reticulum
# 	actin filament
# 	actomyosin
# 	unconventional myosin complex
# molecular functions :
# 	identical protein binding
# 	actin binding
# 	ATP binding
# 	Rab GTPase binding
# 	calcium ion binding
# 	calmodulin binding
# 	disordered domain specific binding
# 	microfilament motor activity
# biological processes :
# 	identical protein binding
# 	actin binding
# 	ATP binding
# 	Rab GTPase binding
# 	calcium ion binding
# 	calmodulin binding
# 	disordered domain specific binding
# 	microfilament motor activity
